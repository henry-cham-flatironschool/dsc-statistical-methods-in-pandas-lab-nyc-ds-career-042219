# %% [markdown]
# # Statistical Methods in Pandas - Lab

# %% [markdown]
# ## Introduction
#
# In this lesson you'll get some hands-on experience using some of the key summary statistics methods in Pandas.

# %% [markdown]
# ## Objectives
# You will be able to:
#
# * Understand and use the df.describe() and df.info() summary statistics methods
# * Use built-in Pandas methods for calculating summary statistics (.mean(), .std(), .count(), .sum(), .mean(), .median(), .std(), .var() and .quantile())
# * Apply a function to every element in a Series or DataFrame using s.apply() and df.applymap()
#
#
# ## Getting Started
#
# For this lab, we'll be working with a dataset containing information on various lego datasets.  You will find this dataset in the file `lego_sets.csv`.
#
# In the cell below:
#
# * Import pandas and set the standard alias of `pd`
# * Load in the `lego_sets.csv` dataset using the `read_csv()` function
# * Display the head of the DataFrame to get a feel for what we'll be working with

# %%
import pandas as pd
df = pd.read_csv('lego_sets.csv')
df.head()
# Out:
#    ages  list_price  num_reviews  piece_count  play_star_rating  \
# 0  6-12       29.99          2.0        277.0               4.0
# 1  6-12       19.99          2.0        168.0               4.0
# 2  6-12       12.99         11.0         74.0               4.3
# 3   12+       99.99         23.0       1032.0               3.6
# 4   12+       79.99         14.0        744.0               3.2
#
#                                            prod_desc  prod_id  \
# 0  Catapult into action and take back the eggs fr...  75823.0
# 1  Launch a flying attack and rescue the eggs fro...  75822.0
# 2  Chase the piggy with lightning-fast Chuck and ...  75821.0
# 3  Explore the architecture of the United States ...  21030.0
# 4  Recreate the Solomon R. Guggenheim Museum® wit...  21035.0
#
#                                       prod_long_desc review_difficulty  \
# 0  Use the staircase catapult to launch Red into ...           Average
# 1  Pilot Pig has taken off from Bird Island with ...              Easy
# 2  Pitch speedy bird Chuck against the Piggy Car....              Easy
# 3  Discover the architectural secrets of the icon...           Average
# 4  Discover the architectural secrets of Frank Ll...       Challenging
#
#                          set_name  star_rating    theme_name  val_star_rating  \
# 0           Bird Island Egg Heist          4.5  Angry Birds™              4.0
# 1              Piggy Plane Attack          5.0  Angry Birds™              4.0
# 2                Piggy Car Escape          4.3  Angry Birds™              4.1
# 3  United States Capitol Building          4.6  Architecture              4.3
# 4   Solomon R. Guggenheim Museum®          4.6  Architecture              4.1
#
#   country
# 0      US
# 1      US
# 2      US
# 3      US
# 4      US

# %%
df = None

# %% [markdown]
# ## Getting DataFrame-Level Statistics
#
# We'll begin by getting some overall summary statistics on the dataset.  There are two ways we'll get this information-- `.info()` and `.describe()`.
#
# ### Using `.info()`
#
# The `.info()` method provides us metadata on the DataFrame itself.  This allows to answer questions such as:
#
# * What data type does each column contain?
# * How many rows are in my dataset?
# * How many total non-missing values does each column contain?
# * How much memory does the DataFrame take up?
#
# In the cell below, call our DataFrame's `.info()` method.

# %% [markdown]
# #### Interpreting the Results
#
# Read the output above, and then answer the following questions:
#
# How many total rows are in this DataFrame?  How many columns contain numeric data? How many contain categorical data?  Identify at least 3 columns that contain missing values.
#
# Write your answer below this line:
# ________________________________________________________________________________________________________________________________

# %% [markdown]
# Answer question here...

# %% [markdown]
# ## Using `.describe()`
#
# Whereas `.info()` provides statistics about the DataFrame itself, `.describe()` returns output containing basic summary statistics about the data contained with the DataFrame.
#
# In the cell below, call the DataFrame's `.describe()` method.

# %% [markdown]
# #### Interpreting the Results
#
# The output contains descriptive statistics corresponding to the columns.  Use these to answer the following questions:
#
# How much is the standard deviation for piece count?  How many pieces are in the largest lego set?  How many in the smallest lego set? What is the median `val_star_rating`?
#
# ________________________________________________________________________________________________________________________________

# %% [markdown]
# Answer questions here...

# %% [markdown]
# ## Getting Summary Statistics
#
# Pandas also allows us to easily compute individual summary statistics using built-in methods.  Next, we'll get some practice using these methods.
#
# In the cell below, compute the median value of the `star_rating` column.

# %% [markdown]
# Next, get a count of the total number of values in `play_star_rating`.

# %% [markdown]
# Now, compute the standard deviation of the `list_price` column.

# %% [markdown]
# If we bought every single lego set in this dataset, how many pieces would we have?  Use the `.sum()` method on the correct column to compute this.

# %%
df.loc[df.duplicated(subset='set_name')]
# Out:
#        ages  list_price  num_reviews  piece_count  play_star_rating  \
# 195     10+      9.9900          5.0        143.0               4.6
# 196     10+      9.9900          3.0        122.0               2.7
# 197     10+      9.9900          1.0        135.0               1.0
# 198     10+      9.9900          2.0        108.0               3.5
# 199     10+     19.9900          NaN        209.0               NaN
# 216     10+      9.9900         11.0         91.0               3.8
# 218     10+      9.9900         12.0        151.0               3.3
# 219     10+      9.9900         10.0        101.0               4.3
# 222     10+      9.9900          9.0         99.0               3.5
# 223    8-12     79.9900          7.0        712.0               3.7
# 224    7-12     24.9900          4.0        206.0               5.0
# 225    7-12     29.9900          2.0        217.0               5.0
# 226    7-12     14.9900          2.0        145.0               4.5
# 227    9-12     99.9900          NaN       1078.0               NaN
# 228    7-12     59.9900          NaN        432.0               NaN
# 229    7-12     44.9900          1.0        351.0               5.0
# 230    7-12     14.9900          2.0        142.0               4.5
# 232    7-14     89.9900          6.0        267.0               4.7
# 269     10+      9.9900          6.0        118.0               3.3
# 274     10+      9.9900          9.0        109.0               3.6
# 275     10+      9.9900         10.0        139.0               4.2
# 276     10+      9.9900          2.0        116.0               5.0
# 337     2-5     19.9900          3.0         29.0               5.0
# 420     4-7     34.9900          2.0        191.0               5.0
# 422     4-7     24.9900          3.0         94.0               4.7
# 423     4-7     24.9900          1.0        151.0               5.0
# 424     4-7     19.9900          2.0        116.0               5.0
# 426     4-7     19.9900          NaN        115.0               NaN
# 427     4-7     19.9900          NaN        115.0               NaN
# 428     4-7     19.9900          2.0         95.0               2.5
# ...     ...         ...          ...          ...               ...
# 12231  7-14     48.7878          5.0        267.0               3.6
# 12232  7-14     48.7878         12.0        293.0               4.9
# 12233  8-14     42.6878         24.0        305.0               4.5
# 12234  7-14     42.6878         18.0        254.0               4.2
# 12235  7-14     30.4878          2.0        198.0               4.0
# 12236  7-14     30.4878          8.0        204.0               4.1
# 12237  7-14     30.4878         19.0        201.0               4.1
# 12238  6-12     18.2878          7.0        141.0               4.0
# 12239  6-12     18.2878         18.0        124.0               4.5
# 12240    5+      4.8678         13.0          8.0               4.3
# 12241  8-14    103.6878          9.0        643.0               4.4
# 12242   16+    365.9878         88.0       4867.0               4.8
# 12243  9-14    225.6878         52.0       2295.0               4.7
# 12244  9-14    134.1878         15.0       1403.0               4.5
# 12245  9-14    103.6878          9.0        830.0               4.6
# 12246  9-14    103.6878         11.0       1202.0               4.7
# 12247  9-14     97.5878          6.0        914.0               4.8
# 12248  9-14     97.5878         19.0        944.0               3.6
# 12249  9-14     82.9478          8.0        876.0               4.7
# 12250  8-14     73.1878          8.0        747.0               4.3
# 12251  8-14     60.9878          7.0        521.0               4.7
# 12252  8-14     60.9878         29.0        544.0               4.6
# 12253  8-14     48.7878         21.0        494.0               4.6
# 12254  7-14     36.5878         10.0        312.0               3.5
# 12255  8-14     36.5878          8.0        341.0               4.2
# 12256  7-14     36.5878          6.0        341.0               4.4
# 12257  7-14     24.3878          8.0        217.0               4.1
# 12258  7-14     24.3878         18.0        233.0               4.6
# 12259  6-14     12.1878          1.0         48.0               5.0
# 12260  6-14     12.1878         11.0        109.0               4.5
#
#                                                prod_desc  prod_id  \
# 195      Stand tall with LEGO® BrickHeadz Wonder Woman™!  41599.0
# 196    Live life in the fast lane with LEGO® BrickHea...  41598.0
# 197              Dive in with LEGO® BrickHeadz Aquaman™!  41600.0
# 198         Get an upgrade with LEGO® BrickHeadz Cyborg™  41601.0
# 199    Join the Justice League™ with LEGO® BrickHeadz...  41610.0
# 216    Celebrate THE LEGO® BATMAN MOVIE with a LEGO B...  41585.0
# 218    Show off the evil trickster with LEGO® BrickHe...  41588.0
# 219    Showcase the Boy Wonder with LEGO® BrickHeadz ...  41587.0
# 222    Channel Batgirl™ with your own LEGO® BrickHead...  41586.0
# 223    Train your skills and learn how to become a Su...  41232.0
# 224    Recover Batgirl’s ePad from the evil Kryptomite™!  41230.0
# 225    Save the super hero café from the evil Kryptom...  41231.0
# 226              Rescue Krypto™ from Lashina’s clutches!  41233.0
# 227         Rescue The Flash™ from Eclipso’s evil plans!  41239.0
# 228    Stop Lena Luthor™ from making evil little Kryp...  41238.0
# 229    Help Batgirl™ nab Mad Harriet™ and recover the...  41237.0
# 230         Keep the crystals from the evil Kryptomites!  41234.0
# 232    With LEGO® Dimensions™, you're gonna need a bi...  71171.0
# 269    Lead a LEGO® BrickHeadz ghost crew featuring D...  41594.0
# 274    Treasure your own LEGO® BrickHeadz constructio...  41593.0
# 275    Add some Disney fairytale romance with a LEGO®...  41595.0
# 276    Bring a classic Disney tale to life with a LEG...  41596.0
# 337    Head off on your holidays with the LEGO® DUPLO...  10590.0
# 420    Roll up for a demolition derby at the Disney•P...  10744.0
# 422    Play in the snow with Anna and Elsa at the ice...  10736.0
# 423        Swoop in with Batman™ and take on the Joker™!  10753.0
# 424    Fix Disney•Pixar’s Lightning McQueen for his n...  10743.0
# 426           Chase down the crook and recover the loot!  10751.0
# 427    Pick up some tasty organic goodies from Mia an...  10749.0
# 428    Smash the speed record with Disney•Pixar’s Lig...  10742.0
# ...                                                  ...      ...
# 12231               Party on with Superman™ and friends!  70919.0
# 12232              Join Batman™ in a comical food fight!  70920.0
# 12233  Put the heat on The Penguin™ Arctic Roller wit...  70911.0
# 12234  Battle with Batman™ against The Riddler™ and h...  70903.0
# 12235  Bring down Captain Boomerang™ with Batman’s Ba...  70918.0
# 12236  Help Batman™ to stop Scarecrow™ delivering a s...  70910.0
# 422                  Anna & Elsa's Frozen Playground          4.7
# 423                        The Joker™ Batcave Attack          5.0
# 424                                  Smokey's Garage          4.5
# 426                            Mountain Police Chase          NaN
# 427                        Mia's Organic Food Market          NaN
# 428                     Willy's Butte Speed Training          3.0
# ...                                              ...          ...
# 12231          The Justice League™ Anniversary Party          3.2
# 12232                       Egghead™ Mech Food Fight          4.8
# 12233                     The Penguin™ Arctic Roller          4.8
# 12234                      The Riddler™ Riddle Racer          4.2
# 12235                             The Bat-Dune Buggy          4.5
# 12236                    Scarecrow™ Special Delivery          4.4
# 12237                         Mr. Freeze™ Ice Attack          4.6
# 12238                    Scarecrow™ Fearful Face-off          4.1
# 12239                      The Joker™ Balloon Escape          4.7
# 12240                THE LEGO® BATMAN MOVIE Series 2          4.8
# 12241                          The Bat-Space Shuttle          4.8
# 12242                                  NINJAGO® City          4.9
# 12243                               Destiny's Bounty          4.9
# 12244         Temple of The Ultimate Ultimate Weapon          4.8
# 12245                  garmadon, Garmadon, GARMADON!          4.9
# 12246                                     Quake Mech          4.5
# 12247                                       Ice Tank          4.8
# 12248                                      Fire Mech          4.2
# 12249                                  Lightning Jet          5.0
# 12250                                Garma Mecha Man          4.5
# 12251                        Garmadon's Volcano Lair          4.3
# 12252                        Green Ninja Mech Dragon          4.7
# 12253                                  Water Strider          4.5
# 12254                                   Master Falls          4.0
# 12255                               Flying Jelly Sub          4.6
# 12256                               Manta Ray Bomber          4.3
# 12257                                 Piranha Attack          3.6
# 12258                            NINJAGO® City Chase          4.6
# 12259                       Lloyd - Spinjitzu Master          5.0
# 12260                             Spinjitzu Training          4.7
#
#                       theme_name  val_star_rating country
# 195                   BrickHeadz              5.0      US
# 196                   BrickHeadz              3.0      US
# 197                   BrickHeadz              3.0      US
# 198                   BrickHeadz              4.0      US
# 199                   BrickHeadz              NaN      US
# 216                   BrickHeadz              4.7      US
# 218                   BrickHeadz              4.7      US
# 219                   BrickHeadz              4.9      US
# 222                   BrickHeadz              4.6      US
# 223          DC Super Hero Girls              3.6      US
# 224          DC Super Hero Girls              4.3      US
# 225          DC Super Hero Girls              4.5      US
# 226          DC Super Hero Girls              5.0      US
# 227          DC Super Hero Girls              NaN      US
# 228          DC Super Hero Girls              NaN      US
# 229          DC Super Hero Girls              5.0      US
# 230          DC Super Hero Girls              3.5      US
# 232                  DIMENSIONS™              4.0      US
# 269                   BrickHeadz              4.7      US
# 274                   BrickHeadz              4.6      US
# 275                   BrickHeadz              4.7      US
# 276                   BrickHeadz              5.0      US
# 337                       DUPLO®              4.7      US
# 420                      Juniors              4.5      US
# 422                      Juniors              4.7      US
# 423                      Juniors              5.0      US
# 424                      Juniors              5.0      US
# 426                      Juniors              NaN      US
# 427                      Juniors              NaN      US
# 428                      Juniors              3.0      US
# ...                          ...              ...     ...
# 12231     THE LEGO® BATMAN MOVIE              3.4      PT
# 12232     THE LEGO® BATMAN MOVIE              4.6      PT
# 12233     THE LEGO® BATMAN MOVIE              4.4      PT
# 12234     THE LEGO® BATMAN MOVIE              4.4      PT
# 12235     THE LEGO® BATMAN MOVIE              4.0      PT
# 12236     THE LEGO® BATMAN MOVIE              4.1      PT
# 12237     THE LEGO® BATMAN MOVIE              4.4      PT
# 12238     THE LEGO® BATMAN MOVIE              4.4      PT
# 12239     THE LEGO® BATMAN MOVIE              4.6      PT
# 12240                Minifigures              4.0      PT
# 12241     THE LEGO® BATMAN MOVIE              3.5      PT
# 12242  THE LEGO® NINJAGO® MOVIE™              4.8      PT
# 12243  THE LEGO® NINJAGO® MOVIE™              4.8      PT
# 12244  THE LEGO® NINJAGO® MOVIE™              4.8      PT
# 12245  THE LEGO® NINJAGO® MOVIE™              4.8      PT
# 12246  THE LEGO® NINJAGO® MOVIE™              4.4      PT
# 12247  THE LEGO® NINJAGO® MOVIE™              4.7      PT
# 12248  THE LEGO® NINJAGO® MOVIE™              4.6      PT
# 12249  THE LEGO® NINJAGO® MOVIE™              4.6      PT
# 12250  THE LEGO® NINJAGO® MOVIE™              4.5      PT
# 12251  THE LEGO® NINJAGO® MOVIE™              5.0      PT
# 12252  THE LEGO® NINJAGO® MOVIE™              4.5      PT
# 12253  THE LEGO® NINJAGO® MOVIE™              4.8      PT
# 12254  THE LEGO® NINJAGO® MOVIE™              3.6      PT
# 12255  THE LEGO® NINJAGO® MOVIE™              4.5      PT
# 12256  THE LEGO® NINJAGO® MOVIE™              4.2      PT
# 12257  THE LEGO® NINJAGO® MOVIE™              4.1      PT
# 12258  THE LEGO® NINJAGO® MOVIE™              4.5      PT
# 12259  THE LEGO® NINJAGO® MOVIE™              5.0      PT
# 12260  THE LEGO® NINJAGO® MOVIE™              4.8      PT
#
# [11520 rows x 14 columns]

# %%
df.loc[df['set_name'] == "The Flash™"]
# Out:
#       ages  list_price  num_reviews  piece_count  play_star_rating  \
# 26     10+      9.9900          3.0        122.0               2.7
# 196    10+      9.9900          3.0        122.0               2.7
# 839    10+     12.1524          3.0        122.0               2.7
# 961    10+     12.1524          3.0        122.0               2.7
# 1408   10+     12.1878          3.0        122.0               2.7
# 1531   10+     12.1878          3.0        122.0               2.7
# 1983   10+     12.1878          3.0        122.0               2.7
# 2106   10+     12.1878          3.0        122.0               2.7
# 2552   10+     10.1322          3.0        122.0               2.7
# 2724   10+     10.1322          3.0        122.0               2.7
# 3365   10+     12.1380          3.0        122.0               2.7
# 3487   10+     12.1380          3.0        122.0               2.7
# 3932   10+     12.4320          3.0        122.0               2.7
# 4055   10+     12.4320          3.0        122.0               2.7
# 4482   10+     12.1878          3.0        122.0               2.7
# 4604   10+     12.1878          3.0        122.0               2.7
# 5031   10+     12.0000          3.0        122.0               2.7
# 5153   10+     12.0000          3.0        122.0               2.7
# 5606   10+     12.1878          3.0        122.0               2.7
# 5728   10+     12.1878          3.0        122.0               2.7
# 6155   10+     15.7990          3.0        122.0               2.7
# 6277   10+     15.7990          3.0        122.0               2.7
# 6704   10+     12.1878          3.0        122.0               2.7
# 6826   10+     12.1878          3.0        122.0               2.7
# 7272   10+     13.9860          3.0        122.0               2.7
# 7394   10+     13.9860          3.0        122.0               2.7
# 7847   10+     12.1878          3.0        122.0               2.7
# 7967   10+     12.1878          3.0        122.0               2.7
# 8416   10+     12.1878          3.0        122.0               2.7
# 8539   10+     12.1878          3.0        122.0               2.7
# 8966   10+     12.1878          3.0        122.0               2.7
# 9089   10+     12.1878          3.0        122.0               2.7
# 9515   10+     12.9870          3.0        122.0               2.7
# 9638   10+     12.9870          3.0        122.0               2.7
# 10065  10+     12.1878          3.0        122.0               2.7
# 10188  10+     12.1878          3.0        122.0               2.7
# 10641  10+     14.1929          3.0        122.0               2.7
# 10763  10+     14.1929          3.0        122.0               2.7
# 11206  10+     13.0471          3.0        122.0               2.7
# 11328  10+     13.0471          3.0        122.0               2.7
# 11734  10+     12.1878          3.0        122.0               2.7
# 11857  10+     12.1878          3.0        122.0               2.7
#
#                                                prod_desc  prod_id  \
# 26     Live life in the fast lane with LEGO® BrickHea...  41598.0
# 196    Live life in the fast lane with LEGO® BrickHea...  41598.0
# 839    Live life in the fast lane with LEGO® BrickHea...  41598.0
# 961    Live life in the fast lane with LEGO® BrickHea...  41598.0
# 1408   Live life in the fast lane with LEGO® BrickHea...  41598.0
# 1531   Live life in the fast lane with LEGO® BrickHea...  41598.0
# 1983   Live life in the fast lane with LEGO® BrickHea...  41598.0
# 2106   Live life in the fast lane with LEGO® BrickHea...  41598.0
# 2552   Live life in the fast lane with LEGO® BrickHea...  41598.0
# 2724   Live life in the fast lane with LEGO® BrickHea...  41598.0
# 3365   Live life in the fast lane with LEGO® BrickHea...  41598.0
# 3487   Live life in the fast lane with LEGO® BrickHea...  41598.0
# 3932   Live life in the fast lane with LEGO® BrickHea...  41598.0
# 4055   Live life in the fast lane with LEGO® BrickHea...  41598.0
# 4482   Live life in the fast lane with LEGO® BrickHea...  41598.0
# 4604   Live life in the fast lane with LEGO® BrickHea...  41598.0
# 5031   Live life in the fast lane with LEGO® BrickHea...  41598.0
# 5153   Live life in the fast lane with LEGO® BrickHea...  41598.0
# 5606   Live life in the fast lane with LEGO® BrickHea...  41598.0
# 5728   Live life in the fast lane with LEGO® BrickHea...  41598.0
# 6155   Live life in the fast lane with LEGO® BrickHea...  41598.0
# 6277   Live life in the fast lane with LEGO® BrickHea...  41598.0
# 6704   Live life in the fast lane with LEGO® BrickHea...  41598.0
# 6826   Live life in the fast lane with LEGO® BrickHea...  41598.0
# 7272   Live life in the fast lane with LEGO® BrickHea...  41598.0
# 7394   Live life in the fast lane with LEGO® BrickHea...  41598.0
# 7847   Live life in the fast lane with LEGO® BrickHea...  41598.0
# 7967   Live life in the fast lane with LEGO® BrickHea...  41598.0
# 8416   Live life in the fast lane with LEGO® BrickHea...  41598.0
# 8539   Live life in the fast lane with LEGO® BrickHea...  41598.0
# 8966   Live life in the fast lane with LEGO® BrickHea...  41598.0
# 9089   Live life in the fast lane with LEGO® BrickHea...  41598.0
# 9515   Live life in the fast lane with LEGO® BrickHea...  41598.0
# 9638   Live life in the fast lane with LEGO® BrickHea...  41598.0
# 10065  Live life in the fast lane with LEGO® BrickHea...  41598.0
# 10188  Live life in the fast lane with LEGO® BrickHea...  41598.0
# 10641  Live life in the fast lane with LEGO® BrickHea...  41598.0
# 10763  Live life in the fast lane with LEGO® BrickHea...  41598.0
# 11206  Live life in the fast lane with LEGO® BrickHea...  41598.0
# 11328  Live life in the fast lane with LEGO® BrickHea...  41598.0
# 11734  Live life in the fast lane with LEGO® BrickHea...  41598.0
# 11857  Live life in the fast lane with LEGO® BrickHea...  41598.0
#
#                                           prod_long_desc review_difficulty  \
# 26     The Flash™ LEGO® BrickHeadz construction chara...         Very Easy
# 196    The Flash™ LEGO® BrickHeadz construction chara...         Very Easy
# 839    The Flash™ LEGO® BrickHeadz construction chara...         Very Easy
# 961    The Flash™ LEGO® BrickHeadz construction chara...         Very Easy
# 1408   The Flash™ LEGO® BrickHeadz construction chara...         Very Easy
# 1531   The Flash™ LEGO® BrickHeadz construction chara...         Very Easy
# 1983   The Flash™ LEGO® BrickHeadz construction chara...         Very Easy
# 2106   The Flash™ LEGO® BrickHeadz construction chara...         Very Easy
# 2552   The Flash™ LEGO® BrickHeadz construction chara...         Very Easy
# 2724   The Flash™ LEGO® BrickHeadz construction chara...         Very Easy
# 3365   The Flash™ LEGO® BrickHeadz construction chara...         Very Easy
# 3487   The Flash™ LEGO® BrickHeadz construction chara...         Very Easy
# 3932   The Flash™ LEGO® BrickHeadz construction chara...         Very Easy
# 4055   The Flash™ LEGO® BrickHeadz construction chara...         Very Easy
# 4482   The Flash™ LEGO® BrickHeadz construction chara...         Very Easy
# 4604   The Flash™ LEGO® BrickHeadz construction chara...         Very Easy
# 5031   The Flash™ LEGO® BrickHeadz construction chara...         Very Easy
# 5153   The Flash™ LEGO® BrickHeadz construction chara...         Very Easy
# 5606   The Flash™ LEGO® BrickHeadz construction chara...         Very Easy
# 5728   The Flash™ LEGO® BrickHeadz construction chara...         Very Easy
# 6155   The Flash™ LEGO® BrickHeadz construction chara...         Very Easy
# 6277   The Flash™ LEGO® BrickHeadz construction chara...         Very Easy
# 6704   The Flash™ LEGO® BrickHeadz construction chara...         Very Easy
# 6826   The Flash™ LEGO® BrickHeadz construction chara...         Very Easy
# 7272   The Flash™ LEGO® BrickHeadz construction chara...         Very Easy
# 7394   The Flash™ LEGO® BrickHeadz construction chara...         Very Easy
# 7847   The Flash™ LEGO® BrickHeadz construction chara...         Very Easy
# 7967   The Flash™ LEGO® BrickHeadz construction chara...         Very Easy
# 8416   The Flash™ LEGO® BrickHeadz construction chara...         Very Easy
# 8539   The Flash™ LEGO® BrickHeadz construction chara...         Very Easy
# 8966   The Flash™ LEGO® BrickHeadz construction chara...         Very Easy
# 9089   The Flash™ LEGO® BrickHeadz construction chara...         Very Easy
# 9515   The Flash™ LEGO® BrickHeadz construction chara...         Very Easy
# 9638   The Flash™ LEGO® BrickHeadz construction chara...         Very Easy
# 10065  The Flash™ LEGO® BrickHeadz construction chara...         Very Easy
# 10188  The Flash™ LEGO® BrickHeadz construction chara...         Very Easy
# 10641  The Flash™ LEGO® BrickHeadz construction chara...         Very Easy
# 10763  The Flash™ LEGO® BrickHeadz construction chara...         Very Easy
# 11206  The Flash™ LEGO® BrickHeadz construction chara...         Very Easy
# 11328  The Flash™ LEGO® BrickHeadz construction chara...         Very Easy
# 11734  The Flash™ LEGO® BrickHeadz construction chara...         Very Easy
# 11857  The Flash™ LEGO® BrickHeadz construction chara...         Very Easy
#
#          set_name  star_rating  theme_name  val_star_rating country
# 26     The Flash™          4.0  BrickHeadz              3.0      US
# 196    The Flash™          4.0  BrickHeadz              3.0      US
# 839    The Flash™          4.0  BrickHeadz              3.0      AU
# 961    The Flash™          4.0  BrickHeadz              3.0      AU
# 1408   The Flash™          4.0  BrickHeadz              3.0      AT
# 1531   The Flash™          4.0  BrickHeadz              3.0      AT
# 1983   The Flash™          4.0  BrickHeadz              3.0      BE
# 2106   The Flash™          4.0  BrickHeadz              3.0      BE
# 2552   The Flash™          4.0  BrickHeadz              3.0      CA
# 2724   The Flash™          4.0  BrickHeadz              3.0      CA
# 3365   The Flash™          4.0  BrickHeadz              3.0      CH
# 3487   The Flash™          4.0  BrickHeadz              3.0      CH
# 3932   The Flash™          4.0  BrickHeadz              3.0      CZ
# 4055   The Flash™          4.0  BrickHeadz              3.0      CZ
# 4482   The Flash™          4.0  BrickHeadz              3.0      DE
# 4604   The Flash™          4.0  BrickHeadz              3.0      DE
# 5031   The Flash™          4.0  BrickHeadz              3.0      DN
# 5153   The Flash™          4.0  BrickHeadz              3.0      DN
# 5606   The Flash™          4.0  BrickHeadz              3.0      ES
# 5728   The Flash™          4.0  BrickHeadz              3.0      ES
# 6155   The Flash™          4.0  BrickHeadz              3.0      FI
# 6277   The Flash™          4.0  BrickHeadz              3.0      FI
# 6704   The Flash™          4.0  BrickHeadz              3.0      FR
# 6826   The Flash™          4.0  BrickHeadz              3.0      FR
# 7272   The Flash™          4.0  BrickHeadz              3.0      GB
# 7394   The Flash™          4.0  BrickHeadz              3.0      GB
# 7847   The Flash™          4.0  BrickHeadz              3.0      IE
# 7967   The Flash™          4.0  BrickHeadz              3.0      IE
# 8416   The Flash™          4.0  BrickHeadz              3.0      IT
# 8539   The Flash™          4.0  BrickHeadz              3.0      IT
# 8966   The Flash™          4.0  BrickHeadz              3.0      LU
# 9089   The Flash™          4.0  BrickHeadz              3.0      LU
# 9515   The Flash™          4.0  BrickHeadz              3.0      NO
# 9638   The Flash™          4.0  BrickHeadz              3.0      NO
# 10065  The Flash™          4.0  BrickHeadz              3.0      NL
# 10188  The Flash™          4.0  BrickHeadz              3.0      NL
# 10641  The Flash™          4.0  BrickHeadz              3.0      NZ
# 10763  The Flash™          4.0  BrickHeadz              3.0      NZ
# 11206  The Flash™          4.0  BrickHeadz              3.0      PL
# 11328  The Flash™          4.0  BrickHeadz              3.0      PL
# 11734  The Flash™          4.0  BrickHeadz              3.0      PT
# 11857  The Flash™          4.0  BrickHeadz              3.0      PT

# %%
df.piece_count.sum()
# Out:
# 6049650.0

# %% [markdown]
# Now, let's try getting the value for the 90% quantile.  Do this in the cell below.

# %% [markdown]
# ## Getting Summary Statistics on Categorical Data
#
# For obvious reasons, most of the methods we've used so far only work with numerical data--there's no way to calculate the standard deviation of a column containing string values. However, there are some things that we can discover about columns containing categorical data.
#
# In the cell below, get the `.unique()` values contained within the `review_difficulty` column.

# %% [markdown]
# Now, let's get the `value_counts` for this column, to see how common each is.

# %% [markdown]
# As you can see, these provide us quick and easy ways to get information on columns containing categorical information.
#
#
# ## Using `.applymap()`
#
# When working with pandas DataFrames, we can quickly compute functions on the data contained by using the `applymap()` function and passing in a lambda function.
#
# For instance, we can use `applymap()` to return a version of the DataFrame where every value has been converted to a string.
#
# In the cell below:
#
# * Call our DataFrame's `.applymap()` function and pass in `lambda x: str(x)`
# * Call our new `string_df` object's `.info()` method to confirm that everything has been cast to a string

# %%
string_df = None

# %% [markdown]
# Note that everything--even the `NaN` values, has been cast to a string in the example above.
#
# Note that for pandas Series objects (such as a single column in a DataFrame), we can do the same thing using the `apply()` method.
#
# This is just one example of how we can quickly compute custom functions on our DataFrame--this will become especially useful when we learn how to **_normalize_** our datasets in a later section!
#
# ## Summary
#
# In this lab, we learned how to:
#
# * Understand and use the df.describe() and df.info() summary statistics methods
# * Use built-in Pandas methods for calculating summary statistics (.mean(), .std(), .count(), .sum(), .mean(), .median(), .std(), .var() and .quantile())
# * Apply a function to every element in a Series or DataFrame using s.apply() and df.applymap()
